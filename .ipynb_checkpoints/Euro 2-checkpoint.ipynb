# %%
from datetime import datetime
from MetaTrader5 import *
MT5Initialize()
MT5WaitForTerminal()

print(MT5TerminalInfo())
print(MT5Version())
# Out:
# [2, 'MetaQuotes-Demo', '21592194']
# [500, 2245, '29 Nov 2019']

# %%
rates = MT5CopyRatesRange("EURUSD", MT5_TIMEFRAME_D1, datetime(2000,1,1), datetime(2019,11,21))

# %%
import pandas as pd
d = pd.DataFrame(list(rates),
                           columns=['time', 'open', 'high', 'low', 'close', 'tick_volume', 'spread', 'real_volume'])

# %%
d['median']=(d['high']+d['low'])/2

# %%
d['delta'] = d['high'].diff(1).fillna(0)

# %%
d
# Out:
#            time     open     high      low    close  tick_volume  spread  \
# 0    2000-01-03  1.00730  1.02780  1.00540  1.02460         6642      50
# 1    2000-01-04  1.02430  1.03400  1.02130  1.02920         7339      50
# 2    2000-01-05  1.02930  1.04020  1.02840  1.03260         6570      50
# 3    2000-01-06  1.03250  1.04150  1.02720  1.03300         7223      50
# 4    2000-01-07  1.03290  1.03320  1.02600  1.02980         5689      50
# ...         ...      ...      ...      ...      ...          ...     ...
# 5166 2019-11-14  1.10052  1.10273  1.09890  1.10212        32577       1
# 5167 2019-11-15  1.10212  1.10567  1.10145  1.10515        27792       1
# 5168 2019-11-18  1.10510  1.10899  1.10477  1.10718        28482       1
# 5169 2019-11-19  1.10718  1.10838  1.10624  1.10780        26644       1
# 5170 2019-11-20  1.10777  1.10813  1.10530  1.10723        34131       1
#
#       real_volume    median    delta
# 0               0  1.016600  0.00000
# 1               0  1.027650  0.00620
# 2               0  1.034300  0.00620
# 3               0  1.034350  0.00130
# 4               0  1.029600 -0.00830
# ...           ...       ...      ...
# 5166            0  1.100815  0.00071
# 5167            0  1.103560  0.00294
# 5168            0  1.106880  0.00332
# 5169            0  1.107310 -0.00061
# 5170            0  1.106715 -0.00025
#
# [5171 rows x 10 columns]

# %%
# %matplotlib nbagg
d['delta'].plot.kde()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import numpy as np
as_strided = np.lib.stride_tricks.as_strided
ln=d['delta'].values
win = 5
v = as_strided(ln, (len(d) - (win - 1), win), (ln.strides * 2))
wn=pd.DataFrame(v,columns=['d1','d2','d3','d4','d5'])
wn
# Out:
#            d1       d2       d3       d4       d5
# 0     0.00000  0.00620  0.00620  0.00130 -0.00830
# 1     0.00620  0.00620  0.00130 -0.00830 -0.00270
# 2     0.00620  0.00130 -0.00830 -0.00270  0.00360
# 3     0.00130 -0.00830 -0.00270  0.00360  0.00290
# 4    -0.00830 -0.00270  0.00360  0.00290 -0.00540
# ...       ...      ...      ...      ...      ...
# 5162 -0.00362 -0.00123 -0.00045 -0.00183  0.00071
# 5163 -0.00123 -0.00045 -0.00183  0.00071  0.00294
# 5164 -0.00045 -0.00183  0.00071  0.00294  0.00332
# 5165 -0.00183  0.00071  0.00294  0.00332 -0.00061
# 5166  0.00071  0.00294  0.00332 -0.00061 -0.00025
#
# [5167 rows x 5 columns]

# %%
from Bayesian import *

# %%
x=wn['d1']
y=wn['d2']
data=np.array([x,y])
robust_model = analyze_robust(data)
with robust_model:
    step = pm.NUTS()
    robust_trace = pm.sample(2000, tune=500, step=step, chains=1, init='nuts')

print(pm.summary(robust_trace))
# Out:
# C:\Users\rando\Anaconda3\lib\site-packages\theano\tensor\basic.py:6611: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result[diagonal_slice] = x
# C:\Users\rando\Anaconda3\lib\site-packages\theano\tensor\basic.py:6611: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result[diagonal_slice] = x
# C:\Users\rando\Anaconda3\lib\site-packages\theano\tensor\basic.py:6611: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result[diagonal_slice] = x
# C:\Users\rando\Anaconda3\lib\site-packages\theano\tensor\basic.py:6611: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result[diagonal_slice] = x
# C:\Users\rando\Anaconda3\lib\site-packages\theano\tensor\basic.py:6611: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result[diagonal_slice] = x
# Sequential sampling (1 chains in 1 job)
# NUTS: [nu_minus_one, r, sigma, mu]
#   0%|                                                                                         | 0/2500 [00:00<?, ?it/s]C:\Users\rando\Anaconda3\lib\site-packages\theano\tensor\basic.py:6611: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result[diagonal_slice] = x
# 100%|██████████████████████████████████████████████████████████████████████████████| 2500/2500 [02:15<00:00, 18.49it/s]
# There were 1998 divergences after tuning. Increase `target_accept` or reparameterize.
# Only one chain was sampled, this makes it impossible to run some convergence checks
#                       mean            sd      mc_error       hpd_2.5  \
# mu__0        -1.000007e+02  4.796963e-05  4.706638e-06 -1.000007e+02
# mu__1         1.000007e+02  2.151065e-04  2.141720e-05  1.000002e+02
# sigma__0      9.998188e-04  1.990365e-07  1.353697e-08  9.993878e-04
# sigma__1      9.998880e-04  1.137888e-07  1.132095e-08  9.996517e-04
# r            -2.143880e-01  1.365286e-07  1.341424e-08 -2.143882e-01
# cov__0_0      9.996376e-07  3.979218e-10  2.706454e-11  9.987760e-07
# cov__0_1     -2.143251e-07  4.859412e-11  3.751046e-12 -2.143875e-07
# cov__1_0     -2.143251e-07  4.859412e-11  3.751046e-12 -2.143875e-07
# cov__1_1      9.997760e-07  2.275361e-10  2.263778e-11  9.993036e-07
# nu_minus_one  9.998686e-01  4.994895e-05  4.984240e-06  9.997982e-01
# nu            1.999869e+00  4.994895e-05  4.984240e-06  1.999798e+00
#
#                   hpd_97.5
# mu__0        -1.000006e+02
# mu__1         1.000010e+02
# sigma__0      1.000000e-03
# sigma__1      9.999994e-04
# r            -2.143878e-01
# cov__0_0      1.000000e-06
# cov__0_1     -2.142313e-07
# cov__1_0     -2.142313e-07
# cov__1_1      9.999989e-07
# nu_minus_one  9.999758e-01
# nu            1.999976e+00

# %%
pm.traceplot(robust_trace['r'])
# Out:
# <img src="data:image/png;base64,..." width="1200">
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001DEED128A48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001DEF191D4C8>]],
#       dtype=object)

# %%
pm.traceplot(robust_trace)
# Out:
# C:\Users\rando\Anaconda3\lib\site-packages\theano\tensor\basic.py:6611: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result[diagonal_slice] = x
# <img src="data:image/png;base64,..." width="1200">
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001DE801F96C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001DE802EEB88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001DE80324C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001DE8035B588>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001DE803907C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001DE802B94C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001DE803DC748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001DE80411908>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001DE80449888>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001DE8047DC88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001DE804B7BC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001DE804ED888>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001DE8052B648>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001DE80563788>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001DE8059BD88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001DE805D7AC8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001DE80611BC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001DE8064C988>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001DE80687708>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001DE806BFFC8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001DE806FAF08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001DE80733B08>]],
#       dtype=object)

# %%
from Bayesian1 import *

# %%
data1=wn.iloc[:,0:2].values
robust_model = analyze_robust1(data1)
with robust_model:
    step = pm.NUTS()
    robust_trace = pm.sample(2000, tune=500, step=step, chains=1, init='nuts')

print(pm.summary(robust_trace))
# Out:
# C:\Users\rando\Anaconda3\lib\site-packages\theano\tensor\basic.py:6611: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result[diagonal_slice] = x
# C:\Users\rando\Anaconda3\lib\site-packages\theano\tensor\basic.py:6611: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result[diagonal_slice] = x
# C:\Users\rando\Anaconda3\lib\site-packages\theano\tensor\basic.py:6611: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result[diagonal_slice] = x
# Sequential sampling (1 chains in 1 job)
# NUTS: [nu, r, sigma, mu]
#   0%|                                                                                         | 0/2500 [00:00<?, ?it/s]C:\Users\rando\Anaconda3\lib\site-packages\theano\tensor\basic.py:6611: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result[diagonal_slice] = x
# 100%|██████████████████████████████████████████████████████████████████████████████| 2500/2500 [01:22<00:00, 30.22it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
#               mean            sd      mc_error   hpd_2.5  hpd_97.5
# mu__0     0.000148  7.804516e-05  1.718210e-06 -0.000002  0.000301
# mu__1     0.000033  8.150514e-05  1.991273e-06 -0.000130  0.000188
# sigma__0  0.004901  7.124935e-05  1.623645e-06  0.004751  0.005031
# sigma__1  0.004899  7.253344e-05  1.655302e-06  0.004759  0.005038
# r         0.110078  1.524999e-02  3.320509e-04  0.080521  0.139427
# cov__0_0  0.000024  6.984417e-07  1.590494e-08  0.000023  0.000025
# cov__0_1  0.000003  3.760914e-07  8.499478e-09  0.000002  0.000003
# cov__1_0  0.000003  3.760914e-07  8.499478e-09  0.000002  0.000003
# cov__1_1  0.000024  7.108549e-07  1.622091e-08  0.000023  0.000025
# nu        3.880519  1.583006e-01  3.687829e-03  3.581006  4.213434

# %%
pm.traceplot(robust_trace['r'])
# Out:
# <img src="data:image/png;base64,..." width="1200">
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001DE808003C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001DEF162A1C8>]],
#       dtype=object)

# %%
ln=d['high'].values
win = 5
v = as_strided(ln, (len(d) - (win - 1), win), (ln.strides * 2))
wn=pd.DataFrame(v,columns=['d1','d2','d3','d4','d5'])
wn
# Out:
#            d1       d2       d3       d4       d5
# 0     1.02780  1.03400  1.04020  1.04150  1.03320
# 1     1.03400  1.04020  1.04150  1.03320  1.03050
# 2     1.04020  1.04150  1.03320  1.03050  1.03410
# 3     1.04150  1.03320  1.03050  1.03410  1.03700
# 4     1.03320  1.03050  1.03410  1.03700  1.03160
# ...       ...      ...      ...      ...      ...
# 5162  1.10553  1.10430  1.10385  1.10202  1.10273
# 5163  1.10430  1.10385  1.10202  1.10273  1.10567
# 5164  1.10385  1.10202  1.10273  1.10567  1.10899
# 5165  1.10202  1.10273  1.10567  1.10899  1.10838
# 5166  1.10273  1.10567  1.10899  1.10838  1.10813
#
# [5167 rows x 5 columns]

# %%
data1=wn.iloc[:,0:2].values
robust_model = analyze_robust1(data1)
with robust_model:
    step = pm.NUTS()
    robust_trace = pm.sample(2000, tune=500, step=step, chains=1, init='nuts')

print(pm.summary(robust_trace))
# Out:
# C:\Users\rando\Anaconda3\lib\site-packages\theano\tensor\basic.py:6611: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result[diagonal_slice] = x
# Sequential sampling (1 chains in 1 job)
# NUTS: [nu, r, sigma, mu]
# 100%|██████████████████████████████████████████████████████████████████████████████| 2500/2500 [12:32<00:00,  3.32it/s]
# The acceptance probability does not match the target. It is 0.9174589606542336, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
#               mean        sd      mc_error   hpd_2.5  hpd_97.5
# mu__0     1.218192  0.002425  7.786827e-05  1.213046  1.222696
# mu__1     1.218241  0.002426  7.775310e-05  1.213109  1.222785
# sigma__0  0.150571  0.001940  6.667354e-05  0.146856  0.154415
# sigma__1  0.150614  0.001940  6.658071e-05  0.146803  0.154418
# r         0.999375  0.000020  6.199784e-07  0.999336  0.999414
# cov__0_0  0.022675  0.000585  2.009931e-05  0.021567  0.023844
# cov__0_1  0.022668  0.000585  2.008275e-05  0.021541  0.023819
# cov__1_0  0.022668  0.000585  2.008275e-05  0.021541  0.023819
# cov__1_1  0.022688  0.000585  2.007581e-05  0.021551  0.023845
# nu        6.179908  0.338703  9.974421e-03  5.560382  6.873682
