# %%
from datetime import datetime
from MetaTrader5 import *
MT5Initialize()
MT5WaitForTerminal()

print(MT5TerminalInfo())
print(MT5Version())
# Out:
# [2, 'MetaQuotes-Demo', '21592194']
# [500, 2245, '29 Nov 2019']

# %%
rates = MT5CopyRatesRange("EURUSD", MT5_TIMEFRAME_D1, datetime(2000,1,1), datetime(2019,11,28))

# %%
import pandas as pd
d = pd.DataFrame(list(rates),
                           columns=['time', 'open', 'high', 'low', 'close', 'tick_volume', 'spread', 'real_volume'])

# %%
d['median']=(d['high']+d['low'])/2
d['delta'] = d['high'].diff(1).fillna(0)

# %%
d
# Out:
#            time     open     high      low    close  tick_volume  spread  \
# 0    2000-01-03  1.00730  1.02780  1.00540  1.02460         6642      50
# 1    2000-01-04  1.02430  1.03400  1.02130  1.02920         7339      50
# 2    2000-01-05  1.02930  1.04020  1.02840  1.03260         6570      50
# 3    2000-01-06  1.03250  1.04150  1.02720  1.03300         7223      50
# 4    2000-01-07  1.03290  1.03320  1.02600  1.02980         5689      50
# ...         ...      ...      ...      ...      ...          ...     ...
# 5171 2019-11-21  1.10723  1.10969  1.10521  1.10581        31829       1
# 5172 2019-11-22  1.10580  1.10875  1.10144  1.10182        32645       1
# 5173 2019-11-25  1.10151  1.10320  1.10035  1.10126        27995       1
# 5174 2019-11-26  1.10129  1.10255  1.10072  1.10194        28638       1
# 5175 2019-11-27  1.10194  1.10246  1.09923  1.09989        29482       1
#
#       real_volume    median    delta
# 0               0  1.016600  0.00000
# 1               0  1.027650  0.00620
# 2               0  1.034300  0.00620
# 3               0  1.034350  0.00130
# 4               0  1.029600 -0.00830
# ...           ...       ...      ...
# 5171            0  1.107450  0.00156
# 5172            0  1.105095 -0.00094
# 5173            0  1.101775 -0.00555
# 5174            0  1.101635 -0.00065
# 5175            0  1.100845 -0.00009
#
# [5176 rows x 10 columns]

# %%
# %matplotlib nbagg
d['delta'].plot.kde()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Мы получили распределение Коши. Дальше этот факт будет учитываться.

# %%
ln=d['delta'].values
import numpy as np
as_strided = np.lib.stride_tricks.as_strided
win = 5
v = as_strided(ln, (len(d) - (win - 1), win), (ln.strides * 2))
wn=pd.DataFrame(v,columns=['d1','d2','d3','d4','d5'])
wn
# Out:
#            d1       d2       d3       d4       d5
# 0     0.00000  0.00620  0.00620  0.00130 -0.00830
# 1     0.00620  0.00620  0.00130 -0.00830 -0.00270
# 2     0.00620  0.00130 -0.00830 -0.00270  0.00360
# 3     0.00130 -0.00830 -0.00270  0.00360  0.00290
# 4    -0.00830 -0.00270  0.00360  0.00290 -0.00540
# ...       ...      ...      ...      ...      ...
# 5167  0.00294  0.00332 -0.00061 -0.00025  0.00156
# 5168  0.00332 -0.00061 -0.00025  0.00156 -0.00094
# 5169 -0.00061 -0.00025  0.00156 -0.00094 -0.00555
# 5170 -0.00025  0.00156 -0.00094 -0.00555 -0.00065
# 5171  0.00156 -0.00094 -0.00555 -0.00065 -0.00009
#
# [5172 rows x 5 columns]

# %%
from scipy.stats import spearmanr
coef, p = spearmanr(wn['d1'], wn['d2'])
print('кореляция ',coef)
print('p-value ',p)
# Out:
# кореляция  0.11172226388792181
# p-value  7.756388462012735e-16

# %% [markdown]
# Определение параметров распределения.

# %%
from stats import *

# %%
model=cauchyvar(d['delta'])
with model:
    trace = pm.sample(2000, tune=1000, step=pm.NUTS(), chains=1, init='nuts')
# Out:
# Sequential sampling (1 chains in 1 job)
# NUTS: [beta, alfa]
# 100%|█████████████████████████████████████████████████████████████████████████████| 3000/3000 [00:13<00:00, 218.57it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks

# %%
print(pm.summary(trace))
# Out:
#           mean        sd  mc_error   hpd_2.5  hpd_97.5
# alfa  0.000046  0.000067  0.000001 -0.000093  0.000173
# beta  0.003164  0.000058  0.000001  0.003046  0.003273

# %%
pm.traceplot(trace)
# Out:
# <img src="data:image/png;base64,..." width="1200">
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A5DC7ABC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020A6360F548>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A5E6B30C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020A63680988>]],
#       dtype=object)

# %% [markdown]
# Все горорят о изменчевости рынка. Давайте проверим изменчив ли наш ряд приращений

# %%
d1=d['delta'].iloc[:1725]
d2=d['delta'].iloc[1725:2*1725]
d3=d['delta'].iloc[2*1725:]

# %%
model1=cauchyvar(d1)
with model1:
    trace1 = pm.sample(2000, tune=1000, step=pm.NUTS(), chains=1, init='nuts')
model2=cauchyvar(d2)
with model2:
    trace2 = pm.sample(2000, tune=1000, step=pm.NUTS(), chains=1, init='nuts')
model3=cauchyvar(d3)
with model3:
    trace3 = pm.sample(2000, tune=1000, step=pm.NUTS(), chains=1, init='nuts')
# Out:
# Sequential sampling (1 chains in 1 job)
# NUTS: [beta, alfa]
# 100%|█████████████████████████████████████████████████████████████████████████████| 3000/3000 [00:06<00:00, 447.57it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Sequential sampling (1 chains in 1 job)
# NUTS: [beta, alfa]
# 100%|█████████████████████████████████████████████████████████████████████████████| 3000/3000 [00:06<00:00, 478.98it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Sequential sampling (1 chains in 1 job)
# NUTS: [beta, alfa]
# 100%|█████████████████████████████████████████████████████████████████████████████| 3000/3000 [00:06<00:00, 473.23it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks

# %%
print(pm.summary(trace1))
print(pm.summary(trace2))
print(pm.summary(trace3))
# Out:
#           mean        sd  mc_error   hpd_2.5  hpd_97.5
# alfa  0.000234  0.000122  0.000002 -0.000007  0.000470
# beta  0.003244  0.000102  0.000002  0.003049  0.003446
#           mean        sd  mc_error   hpd_2.5  hpd_97.5
# alfa  0.000256  0.000144  0.000003 -0.000016  0.000543
# beta  0.003888  0.000124  0.000003  0.003644  0.004124
#           mean        sd  mc_error   hpd_2.5  hpd_97.5
# alfa -0.000224  0.000092  0.000002 -0.000399 -0.000037
# beta  0.002520  0.000081  0.000002  0.002363  0.002675

# %% [markdown]
# Изменения в показателе beta значительные. Характер рынка меняется. Это подтверждает то, что рынок изменчив.

# %%
v1,v2,v3=verbar(d['delta'])
print('вверх ',v1)
print('вниз ',v2)
print('равно ',v3)
# Out:
# вверх  0.4947836166924266
# вниз  0.500772797527048
# равно  0.004443585780525503

# %%
data=d['delta'].iloc[1524:2165]
data1=data.tolist()

# %%
model4=cauchyvar(data1)
with model4:
    trace4 = pm.sample(2000, tune=1000, step=pm.NUTS(), chains=1, init='nuts')
# Out:
# Sequential sampling (1 chains in 1 job)
# NUTS: [beta, alfa]
# 100%|█████████████████████████████████████████████████████████████████████████████| 3000/3000 [00:04<00:00, 670.55it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks

# %%
print(pm.summary(trace4))
# Out:
#           mean        sd  mc_error   hpd_2.5  hpd_97.5
# alfa  0.000344  0.000176  0.000004 -0.000026  0.000665
# beta  0.002851  0.000147  0.000003  0.002561  0.003133

# %%
data.plot.kde()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# График распеределения для тренда. На глаз заметен дисбаланс для роста цены. Поэтому тренд объясняется тем что цена в пунктах
# растет больше для восходящего тренда, а верояность того что на следующий день будет рост примерно равна 50%

# %% [markdown]
# распределение при крахе рынка

# %%
d['median'].plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# i1=2222 i2=2297

# %%
data3=d['delta'].iloc[2222:2297]
data3.plot.kde()
# Out:
# <img src="data:image/png;base64,..." width="640">
